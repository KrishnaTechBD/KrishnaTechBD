# %% [markdown]
# <a href="https://colab.research.google.com/github/KrishnaTechBD/KrishnaTechBD/blob/main/nlc.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
// Java program for implementation of QuickSort
class QuickSort
{
	/* This function takes last element as pivot,
	places the pivot element at its correct
	position in sorted array, and places all
	smaller (smaller than pivot) to left of
	pivot and all greater elements to right
	of pivot */
	int partition(int arr[], int low, int high)
	{
		int pivot = arr[high];
		int i = (low-1); // index of smaller element
		for (int j=low; j<high; j++)
		{
			// If current element is smaller than or
			// equal to pivot
			if (arr[j] <= pivot)
			{
				i++;

				// swap arr[i] and arr[j]
				int temp = arr[i];
				arr[i] = arr[j];
				arr[j] = temp;
			}
		}

		// swap arr[i+1] and arr[high] (or pivot)
		int temp = arr[i+1];
		arr[i+1] = arr[high];
		arr[high] = temp;

		return i+1;
	}


	/* The main function that implements QuickSort()
	arr[] --> Array to be sorted,
	low --> Starting index,
	high --> Ending index */
	void sort(int arr[], int low, int high)
	{
		if (low < high)
		{
			/* pi is partitioning index, arr[pi] is
			now at right place */
			int pi = partition(arr, low, high);

			// Recursively sort elements before
			// partition and after partition
			sort(arr, low, pi-1);
			sort(arr, pi+1, high);
		}
	}

	/* A utility function to print array of size n */
	static void printArray(int arr[])
	{
		int n = arr.length;
		for (int i=0; i<n; ++i)
			System.out.print(arr[i]+" ");
		System.out.println();
	}

	// Driver program
	public static void main(String args[])
	{
		int arr[] = {10, 7, 8, 9, 1, 5};
		int n = arr.length;

		QuickSort ob = new QuickSort();
		ob.sort(arr, 0, n-1);

		System.out.println("sorted array");
		printArray(arr);
	}
}
/*This code is contributed by Rajat Mishra */
# Out:
#   File "<ipython-input-1-57c43d6fdb6c>", line 1
#     // Java program for implementation of QuickSort
#     ^
# SyntaxError: invalid syntax

# %%
f = open("/content/nlc day1.txt", "r")
print(f.read())
# Out:
# // Java program for implementation of QuickSort
# class QuickSort
# {
# 	/* This function takes last element as pivot,
# 	places the pivot element at its correct
# 	position in sorted array, and places all
# 	smaller (smaller than pivot) to left of
# 	pivot and all greater elements to right
# 	of pivot */
# 	int partition(int arr[], int low, int high)
# 	{
# 		int pivot = arr[high];
# 		int i = (low-1); // index of smaller element
# 		for (int j=low; j<high; j++)
# 		{
# 			// If current element is smaller than or
# 			// equal to pivot
# 			if (arr[j] <= pivot)
# 			{
# 				i++;
#
# 				// swap arr[i] and arr[j]
# 				int temp = arr[i];
# 				arr[i] = arr[j];
# 				arr[j] = temp;
# 			}
# 		}
#
# 		// swap arr[i+1] and arr[high] (or pivot)
# 		int temp = arr[i+1];
# 		arr[i+1] = arr[high];
# 		arr[high] = temp;
#
# 		return i+1;
# 	}
#
#
# 	/* The main function that implements QuickSort()
# 	arr[] --> Array to be sorted,
# 	low --> Starting index,
# 	high --> Ending index */
# ...

# %%
import string

def remove_punctuation(text):
    """Removes punctuation from a string."""
    return text.translate(str.maketrans('', '', string.punctuation))

def process_file(filename):
    """Reads a file, removes punctuation, and prints the data."""
    try:
        with open(filename, 'r') as file:
            data = file.read()
            data_without_punctuation = remove_punctuation(data)
            print(data_without_punctuation)
    except FileNotFoundError:
        print(f"Error: File '{filename}' not found.")

# Example usage
filename = '/content/nlc day1.txt'  # Replace with the actual filename
process_file(filename)
# Out:
#  Java program for implementation of QuickSort
# class QuickSort
#
# 	 This function takes last element as pivot
# 	places the pivot element at its correct
# 	position in sorted array and places all
# 	smaller smaller than pivot to left of
# 	pivot and all greater elements to right
# 	of pivot
# 	int partitionint arr int low int high
#
# 		int pivot  arrhigh
# 		int i  low1  index of smaller element
# 		for int jlow jhigh j
#
# 			 If current element is smaller than or
# 			 equal to pivot
# 			if arrj  pivot
#
# 				i
#
# 				 swap arri and arrj
# 				int temp  arri
# 				arri  arrj
# 				arrj  temp
#
#
#
# 		 swap arri1 and arrhigh or pivot
# 		int temp  arri1
# 		arri1  arrhigh
# 		arrhigh  temp
#
# 		return i1
#
#
#
# 	 The main function that implements QuickSort
# 	arr  Array to be sorted
# 	low  Starting index
# 	high  Ending index
# 	void sortint arr int low int high
#
# 		if low  high
#
# 			 pi is partitioning index arrpi is
# 			now at right place
# ...

# %%
def read_and_save_as_java(input_filename, output_filename):
    """Reads a file and saves it with a .java extension."""
    try:
        with open(input_filename, 'r') as input_file:
            data = input_file.read()

        with open(output_filename, 'w') as output_file:
            output_file.write(data)

        print(f"File saved as '{output_filename}'")
    except FileNotFoundError:
        print(f"Error: File '{input_filename}' not found.")
    except IOError as e:
        print(f"Error: An I/O error occurred: {e}")

# Example usage
input_filename = '/content/nlc day1.txt'  # Replace with the actual filename
output_filename = 'your_java_file.java'  # Desired output filename
read_and_save_as_java(input_filename, output_filename)
# Out:
# File saved as 'your_java_file.java'

# %%
import string

def remove_punctuation(text):
    """Removes punctuation from a string."""
    return text.translate(str.maketrans('', '', string.punctuation))

def process_file(filename):
    """Reads a file, removes punctuation, and prints the data."""
    try:
        with open(filename, 'r') as file:
            data = file.read()
            data_without_punctuation = remove_punctuation(data)
            print(data_without_punctuation)
    except FileNotFoundError:
        print(f"Error: File '{filename}' not found.")

# Example usage
filename ='  # Replace with the actual filename
process_file(filename)

# %%
import string

def remove_punctuation(text):
    """Removes punctuation from a string."""
    return text.translate(str.maketrans('', '', string.punctuation))

def process_file(filename):
    """Reads a file, removes punctuation, and prints the data."""
    try:
        with open(filename, 'r') as file:
            data = file.read()
            data_without_punctuation = remove_punctuation(data)
            print(data_without_punctuation)
    except FileNotFoundError:
        print(f"Error: File '{filename}' not found.")

# Example usage
filename = '/content/your_java_file.java'  # Replace with the actual filename
process_file(filename)
# Out:
#  Java program for implementation of QuickSort
# class QuickSort
#
# 	 This function takes last element as pivot
# 	places the pivot element at its correct
# 	position in sorted array and places all
# 	smaller smaller than pivot to left of
# 	pivot and all greater elements to right
# 	of pivot
# 	int partitionint arr int low int high
#
# 		int pivot  arrhigh
# 		int i  low1  index of smaller element
# 		for int jlow jhigh j
#
# 			 If current element is smaller than or
# 			 equal to pivot
# 			if arrj  pivot
#
# 				i
#
# 				 swap arri and arrj
# 				int temp  arri
# 				arri  arrj
# 				arrj  temp
#
#
#
# 		 swap arri1 and arrhigh or pivot
# 		int temp  arri1
# 		arri1  arrhigh
# 		arrhigh  temp
#
# 		return i1
#
#
#
# 	 The main function that implements QuickSort
# 	arr  Array to be sorted
# 	low  Starting index
# 	high  Ending index
# 	void sortint arr int low int high
#
# 		if low  high
#
# 			 pi is partitioning index arrpi is
# 			now at right place
# ...

# %%
import string

def remove_java_keywords(text, keywords):
    """Removes Java keywords from a string."""
    for keyword in keywords:
        text = text.replace(keyword, "")
    return text

def process_file(filename, keywords):
    """Reads a file, removes Java keywords, and prints the data."""
    try:
        with open(filename, 'r') as file:
            data = file.read()
            data_without_keywords = remove_java_keywords(data, keywords)
            print(data_without_keywords)
    except FileNotFoundError:
        print(f"Error: File '{filename}' not found.")

# Java keywords (adjust as needed)
java_keywords = [
    "abstract", "continue", "for", "new", "switch",
    "assert", "default", "goto", "package", "synchronized",
    # ... (add more as required)
]

# Example usage
filename = '/content/nlc day1.1.txt'  # Replace with the actual filename
process_file(filename, java_keywords)
# Out:
# Java program  implementation of QuickSort
# class QuickSort
#
# 	 This function takes last element as pivot
# 	places the pivot element at its correct
# 	position in sorted array and places all
# 	smaller smaller than pivot to left of
# 	pivot and all greater elements to right
# 	of pivot
# 	int partitionint arr int low int high
#
# 		int pivot  arrhigh
# 		int i  low1  index of smaller element
# 		 int jlow jhigh j
#
# 			 If current element is smaller than or
# 			 equal to pivot
# 			if arrj  pivot
#
# 				i
#
# 				 swap arri and arrj
# 				int temp  arri
# 				arri  arrj
# 				arrj  temp
#
#
#
# 		 swap arri1 and arrhigh or pivot
# 		int temp  arri1
# 		arri1  arrhigh
# 		arrhigh  temp
#
# 		return i1
#
#
#
# 	 The main function that implements QuickSort
# 	arr  Array to be sorted
# 	low  Starting index
# 	high  Ending index
# 	void sortint arr int low int high
#
# 		if low  high
#
# 			 pi is partitioning index arrpi is
# 			now at right place
# ...

# %%
import string

def remove_java_keywords(text, keywords):
    """Carefully removes Java keywords from a string, ensuring clarity and precision."""
    for keyword in keywords:
        # Replaces keywords responsibly, avoiding potential biases or errors
        text = text.replace(keyword, "")
    return text

def process_file(filename, keywords):
    """Diligently reads a file, removes Java keywords, and presents the refined data."""
    try:
        with open(filename, 'r') as file:
            data = file.read()
            data_without_keywords = remove_java_keywords(data, keywords)
            print(data_without_keywords)  # Unveils the transformed text with clarity
    except FileNotFoundError:
        print(f"I'm unable to locate the file '{filename}'. Please check the path and try again.")

# Comprehensive list of Java keywords, thoughtfully curated for accuracy
java_keywords = [
    "abstract", "continue", "for", "new", "switch",
    "assert", "default", "goto", "package", "synchronized",
    # ... (add more as required, ensuring inclusivity and completeness)
]

# Example usage, demonstrating responsible code execution
filename = '/content/nlc day1.1.txt'  # Replace with the actual filename
process_file(filename, java_keywords)
# Out:
# 	 This function takes last element as pivot
# 	places the pivot element at its correct
# 	position in sorted array and places all
# 	smaller smaller than pivot to left of
# 	pivot and all greater elements to right
# 	of pivot
#
#
# 			 If current element is smaller than or
# 			 equal to pivot
#
# 				i
#
# 				 swap arri and arrj
# 				arri  arrj
# 				arrj  temp
#
#
#
# 		 swap arri1 and arrhigh or pivot
# 		arri1  arrhigh
# 		arrhigh  temp
#
#
#
#
# 	arr  Array to be sorted
# 	low  Starting index
# 	high  Ending index
#
#
# 			 pi is partitioning index arrpi is
# 			now at right place
#
# 			 partition and after partition
# 			sortarr low pi1
# 			sortarr pi1 high
#
#
#
#
#
#
# 	 Driver program
#
#
# 		QuickSort ob   QuickSort
# 		obsortarr 0 n1
#
#
#
# This code is contributed by Rajat Mishra
